# %% [markdown]
# # IMPORT

# %%
import pandas as pd

# %%
df = pd.read_csv("orders.csv")
print(df)
# Out:
#     OrderID      CustomerName                Product     Category  Quantity  \
# 0      1001        John Smith                 Laptop  Electronics         1
# 1      1002         Sarah Lee             Headphones  Electronics         2
# 2      1003          Ali Khan           Office Chair    Furniture         1
# 3      1004        Alice Wong              Desk Lamp    Furniture         3
# 4      1005     Carlos Mendez               Keyboard  Electronics         2
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 6      1007       Emily Davis          Standing Desk    Furniture         1
# 7      1008        James Park                Monitor  Electronics         2
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 9      1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10     1011     Sophie Martin                 Webcam  Electronics         1
# ...

# %%
df.head() # gives first 5 rows of the DATAFRAME
# Out:
#    OrderID   CustomerName       Product     Category  Quantity   Price  \
# 0     1001     John Smith        Laptop  Electronics         1  1200.0
# 1     1002      Sarah Lee    Headphones  Electronics         2   150.0
# 2     1003       Ali Khan  Office Chair    Furniture         1   300.0
# 3     1004     Alice Wong     Desk Lamp    Furniture         3    45.0
# 4     1005  Carlos Mendez      Keyboard  Electronics         2    80.0
#
#     OrderDate Shipped    Country
# 0  2024-06-01     Yes        USA
# 1  2024-06-03      No     Canada
# 2  2024-06-04     Yes        UAE
# 3  2024-06-05     Yes  Singapore
# 4  2024-06-06      No     Mexico

# %%
df.tail() # Gives last 5 rows of the DATAFRAME
# Out:
#     OrderID    CustomerName             Product     Category  Quantity  Price  \
# 35     1036   Emma Thompson  Desk Lamp with USB    Furniture         1   68.0
# 36     1037   Carlos Santos    Wireless Earbuds  Electronics         1  125.0
# 37     1038  Leila Mansouri            Desk Pad    Furniture         1   28.0
# 38     1039      Daniel Kim         Power Strip  Electronics         2   18.0
# 39     1040    Anna Ivanova          Desk Clock    Furniture         1   35.0
#
#      OrderDate Shipped      Country
# 35  2024-07-07      No           UK
# 36  2024-07-08     Yes     Portugal
# 37  2024-07-09     Yes         Iran
# 38  2024-07-10      No  South Korea
# 39  2024-07-11     Yes      Ukraine

# %%
df.info() #Gives general info of the DATAFRAME
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderID       40 non-null     int64
#  1   CustomerName  40 non-null     str
#  2   Product       40 non-null     str
#  3   Category      40 non-null     str
#  4   Quantity      40 non-null     int64
#  5   Price         40 non-null     float64
#  6   OrderDate     40 non-null     str
#  7   Shipped       40 non-null     str
#  8   Country       40 non-null     str
# dtypes: float64(1), int64(2), str(6)
# memory usage: 2.9 KB

# %%
df.describe() # Gives the descriptive statistics
# Out:
#            OrderID    Quantity        Price
# count    40.000000   40.000000    40.000000
# mean   1020.500000    5.450000   106.457500
# std      11.690452   15.903475   201.091854
# min    1001.000000    1.000000     0.800000
# 25%    1010.750000    1.000000    18.000000
# 50%    1020.500000    1.000000    43.500000
# 75%    1030.250000    2.250000   112.500000
# max    1040.000000  100.000000  1200.000000

# %%
df.columns # gives list of all of the diff cols
# Out:
# Index(['OrderID', 'CustomerName', 'Product', 'Category', 'Quantity', 'Price',
#        'OrderDate', 'Shipped', 'Country'],
#       dtype='str')

# %%
df.index # gives us the range of index
# Out:
# RangeIndex(start=0, stop=40, step=1)

# %% [markdown]
# ## Modfying and Accessing

# %%
df["Country"] # I can use len() to find no of countries
#or set() to find uniq countries
# Out:
# 0              USA
# 1           Canada
# 2              UAE
# 3        Singapore
# 4           Mexico
# 5              UAE
# 6               UK
# 7      South Korea
# 8            Italy
# 9            Japan
# 10          France
# 11           India
# 12       Australia
# 13           Spain
# 14           China
# 15           Egypt
# 16          Poland
# 17             USA
# 18           Japan
# 19    Saudi Arabia
# 20          Canada
# 21          Brazil
# 22         Germany
# 23        Pakistan
# 24          Sweden
# 25          France
# 26       Argentina
# 27          Russia
# 28     South Korea
# 29           Italy
# 30         Morocco
# 31         Germany
# 32        Colombia
# 33             USA
# 34           Japan
# 35              UK
# 36        Portugal
# 37            Iran
# 38     South Korea
# 39         Ukraine
# Name: Country, dtype: str

# %%
df[["Country","Product"]] #Indexing Based on multiple cols
# returns new dataframe
# Out:
#          Country                Product
# 0            USA                 Laptop
# 1         Canada             Headphones
# 2            UAE           Office Chair
# 3      Singapore              Desk Lamp
# 4         Mexico               Keyboard
# 5            UAE               Notebook
# 6             UK          Standing Desk
# 7    South Korea                Monitor
# 8          Italy                    Pen
# 9          Japan                  Mouse
# 10        France                 Webcam
# 11         India           File Cabinet
# 12     Australia                Stapler
# 13         Spain              USB Drive
# 14         China              Bookshelf
# 15         Egypt          Printer Paper
# 16        Poland         Wireless Mouse
# 17           USA         Desk Organizer
# 18         Japan             Calculator
# 19  Saudi Arabia             Whiteboard
# 20        Canada           Highlighters
# 21        Brazil      Bluetooth Speaker
# ...

# %%
# indexing based on row
# returns all values of that row
df.iloc[0]
# Out:
# OrderID                1001
# CustomerName     John Smith
# Product              Laptop
# Category        Electronics
# Quantity                  1
# Price                1200.0
# OrderDate        2024-06-01
# Shipped                 Yes
# Country                 USA
# Name: 0, dtype: object

# %%
list(df.iloc[0])
# Out:
# [np.int64(1001),
#  'John Smith',
#  'Laptop',
#  'Electronics',
#  np.int64(1),
#  np.float64(1200.0),
#  '2024-06-01',
#  'Yes',
#  'USA']

# %%
df.iloc[0]["Country"]
# Out:
# 'USA'

# %% [markdown]
# ## Filtering

# %%
df[df["Category"]=="Electronics"] ## SIngle filter
# Out:
#     OrderID      CustomerName            Product     Category  Quantity  \
# 0      1001        John Smith             Laptop  Electronics         1
# 1      1002         Sarah Lee         Headphones  Electronics         2
# 4      1005     Carlos Mendez           Keyboard  Electronics         2
# 7      1008        James Park            Monitor  Electronics         2
# 9      1010  Takeshi Nakamura              Mouse  Electronics         1
# 10     1011     Sophie Martin             Webcam  Electronics         1
# 13     1014   Diego Rodriguez          USB Drive  Electronics         5
# 16     1017     Anna Kowalski     Wireless Mouse  Electronics         2
# 18     1019       Yuki Tanaka         Calculator  Electronics         1
# 21     1022    Isabella Silva  Bluetooth Speaker  Electronics         1
# 24     1025    Lucas Anderson       Tablet Stand  Electronics         1
# 25     1026      Chloe Dubois     Paper Shredder  Electronics         1
# ...

# %%
# Multiple Filter

df[(df["Category"]=='Electronics') &(df["Country"]=='USA') ]
# Out:
#    OrderID CustomerName Product     Category  Quantity   Price   OrderDate  \
# 0     1001   John Smith  Laptop  Electronics         1  1200.0  2024-06-01
#
#   Shipped Country
# 0     Yes     USA

# %%
df[(df["Category"]=='Electronics') | (df["Country"]=='USA') ]
# Out:
#     OrderID      CustomerName            Product     Category  Quantity  \
# 0      1001        John Smith             Laptop  Electronics         1
# 1      1002         Sarah Lee         Headphones  Electronics         2
# 4      1005     Carlos Mendez           Keyboard  Electronics         2
# 7      1008        James Park            Monitor  Electronics         2
# 9      1010  Takeshi Nakamura              Mouse  Electronics         1
# 10     1011     Sophie Martin             Webcam  Electronics         1
# 13     1014   Diego Rodriguez          USB Drive  Electronics         5
# 16     1017     Anna Kowalski     Wireless Mouse  Electronics         2
# 17     1018     Michael Brown     Desk Organizer    Furniture         1
# 18     1019       Yuki Tanaka         Calculator  Electronics         1
# 21     1022    Isabella Silva  Bluetooth Speaker  Electronics         1
# 24     1025    Lucas Anderson       Tablet Stand  Electronics         1
# ...

# %%
df[df['Quantity']>=20]
# Out:
#     OrderID  CustomerName        Product    Category  Quantity  Price  \
# 15     1016  Ahmed Hassan  Printer Paper  Stationery        20    8.0
# 33     1034  Alex Johnson    Index Cards  Stationery       100    0.8
#
#      OrderDate Shipped Country
# 15  2024-06-17     Yes   Egypt
# 33  2024-07-05     Yes     USA

# %%
df[df['Country'].isin(["USA"])]
# Out:
#     OrderID   CustomerName         Product     Category  Quantity   Price  \
# 0      1001     John Smith          Laptop  Electronics         1  1200.0
# 17     1018  Michael Brown  Desk Organizer    Furniture         1    65.0
# 33     1034   Alex Johnson     Index Cards   Stationery       100     0.8
#
#      OrderDate Shipped Country
# 0   2024-06-01     Yes     USA
# 17  2024-06-19      No     USA
# 33  2024-07-05     Yes     USA

# %%
df[~df['Country'].isin(["USA"])]
# Out:
#     OrderID      CustomerName                Product     Category  Quantity  \
# 1      1002         Sarah Lee             Headphones  Electronics         2
# 2      1003          Ali Khan           Office Chair    Furniture         1
# 3      1004        Alice Wong              Desk Lamp    Furniture         3
# 4      1005     Carlos Mendez               Keyboard  Electronics         2
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 6      1007       Emily Davis          Standing Desk    Furniture         1
# 7      1008        James Park                Monitor  Electronics         2
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 9      1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10     1011     Sophie Martin                 Webcam  Electronics         1
# 11     1012         Raj Patel           File Cabinet    Furniture         2
# ...

# %% [markdown]
# ## Deleting or Updating Data

# %%
df.loc[df['CustomerName']=="Anna Ivanova","Product"] = "Tim"

# %%
df.loc[df['CustomerName']=="Anna Ivanova"]
# Out:
#     OrderID  CustomerName Product   Category  Quantity  Price   OrderDate  \
# 39     1040  Anna Ivanova     Tim  Furniture         1   35.0  2024-07-11
#
#    Shipped  Country
# 39     Yes  Ukraine

# %%
df.loc[df['Country']=="USA","Country"] = "United States"

# %%
df.loc[df['Country']=="United States"]
# Out:
#     OrderID   CustomerName         Product     Category  Quantity   Price  \
# 0      1001     John Smith          Laptop  Electronics         1  1200.0
# 17     1018  Michael Brown  Desk Organizer    Furniture         1    65.0
# 33     1034   Alex Johnson     Index Cards   Stationery       100     0.8
#
#      OrderDate Shipped        Country
# 0   2024-06-01     Yes  United States
# 17  2024-06-19      No  United States
# 33  2024-07-05     Yes  United States

# %% [markdown]
# ### Up until above was just changing rows

# %% [markdown]
# ---

# %% [markdown]
# ### Down here we changing cols

# %%
df["Country"] = df["Country"].str.upper()

# %%
df["Country"]
# Out:
# 0     UNITED STATES
# 1            CANADA
# 2               UAE
# 3         SINGAPORE
# 4            MEXICO
# 5               UAE
# 6                UK
# 7       SOUTH KOREA
# 8             ITALY
# 9             JAPAN
# 10           FRANCE
# 11            INDIA
# 12        AUSTRALIA
# 13            SPAIN
# 14            CHINA
# 15            EGYPT
# 16           POLAND
# 17    UNITED STATES
# 18            JAPAN
# 19     SAUDI ARABIA
# 20           CANADA
# 21           BRAZIL
# 22          GERMANY
# 23         PAKISTAN
# 24           SWEDEN
# 25           FRANCE
# 26        ARGENTINA
# 27           RUSSIA
# 28      SOUTH KOREA
# 29            ITALY
# 30          MOROCCO
# 31          GERMANY
# 32         COLOMBIA
# 33    UNITED STATES
# 34            JAPAN
# 35               UK
# 36         PORTUGAL
# 37             IRAN
# 38      SOUTH KOREA
# 39          UKRAINE
# Name: Country, dtype: str

# %%
df = df.drop(39) # drops the row at index 39

# %%
df.tail()
# Out:
#     OrderID    CustomerName             Product     Category  Quantity  Price  \
# 34     1035   Yuki Yamamoto       Monitor Stand  Electronics         1   55.0
# 35     1036   Emma Thompson  Desk Lamp with USB    Furniture         1   68.0
# 36     1037   Carlos Santos    Wireless Earbuds  Electronics         1  125.0
# 37     1038  Leila Mansouri            Desk Pad    Furniture         1   28.0
# 38     1039      Daniel Kim         Power Strip  Electronics         2   18.0
#
#      OrderDate Shipped      Country
# 34  2024-07-06     Yes        JAPAN
# 35  2024-07-07      No           UK
# 36  2024-07-08     Yes     PORTUGAL
# 37  2024-07-09     Yes         IRAN
# 38  2024-07-10      No  SOUTH KOREA

# %% [markdown]
# ## Cleaning Data

# %%
df = pd.read_csv("Orders.csv")

# %%
df
# Out:
#     OrderID      CustomerName                Product     Category  Quantity  \
# 0      1001        John Smith                 Laptop  Electronics         1
# 1      1002         Sarah Lee             Headphones  Electronics         2
# 2      1003          Ali Khan           Office Chair    Furniture         1
# 3      1004        Alice Wong              Desk Lamp    Furniture         3
# 4      1005     Carlos Mendez               Keyboard  Electronics         2
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 6      1007       Emily Davis          Standing Desk    Furniture         1
# 7      1008        James Park                Monitor  Electronics         2
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 9      1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10     1011     Sophie Martin                 Webcam  Electronics         1
# ...

# %%
df.dropna() # drops anything that contains NA or null values
# Out:
#     OrderID      CustomerName                Product     Category  Quantity  \
# 0      1001        John Smith                 Laptop  Electronics         1
# 1      1002         Sarah Lee             Headphones  Electronics         2
# 2      1003          Ali Khan           Office Chair    Furniture         1
# 3      1004        Alice Wong              Desk Lamp    Furniture         3
# 4      1005     Carlos Mendez               Keyboard  Electronics         2
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 6      1007       Emily Davis          Standing Desk    Furniture         1
# 7      1008        James Park                Monitor  Electronics         2
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 9      1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10     1011     Sophie Martin                 Webcam  Electronics         1
# ...

# %%
df.fillna({"OrdersID":0},inplace = True) # rather than dropping fils null entries with given one
# Out:
#     OrderID      CustomerName                Product     Category  Quantity  \
# 0      1001        John Smith                 Laptop  Electronics         1
# 1      1002         Sarah Lee             Headphones  Electronics         2
# 2      1003          Ali Khan           Office Chair    Furniture         1
# 3      1004        Alice Wong              Desk Lamp    Furniture         3
# 4      1005     Carlos Mendez               Keyboard  Electronics         2
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 6      1007       Emily Davis          Standing Desk    Furniture         1
# 7      1008        James Park                Monitor  Electronics         2
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 9      1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10     1011     Sophie Martin                 Webcam  Electronics         1
# ...

# %%
df.rename(columns = {"OrderID":"Order ID"},inplace = True)

# %%
df.head()
# Out:
#    Order ID   CustomerName       Product     Category  Quantity   Price  \
# 0      1001     John Smith        Laptop  Electronics         1  1200.0
# 1      1002      Sarah Lee    Headphones  Electronics         2   150.0
# 2      1003       Ali Khan  Office Chair    Furniture         1   300.0
# 3      1004     Alice Wong     Desk Lamp    Furniture         3    45.0
# 4      1005  Carlos Mendez      Keyboard  Electronics         2    80.0
#
#     OrderDate Shipped    Country
# 0  2024-06-01     Yes        USA
# 1  2024-06-03      No     Canada
# 2  2024-06-04     Yes        UAE
# 3  2024-06-05     Yes  Singapore
# 4  2024-06-06      No     Mexico

# %% [markdown]
# ## Analyzing Data

# %%
df["Country"].value_counts()
# Out:
# Country
# USA             3
# South Korea     3
# Japan           3
# Canada          2
# UAE             2
# UK              2
# Italy           2
# France          2
# Germany         2
# Singapore       1
# Mexico          1
# India           1
# Australia       1
# Spain           1
# China           1
# Egypt           1
# Poland          1
# Saudi Arabia    1
# Brazil          1
# Pakistan        1
# Sweden          1
# Argentina       1
# Russia          1
# Morocco         1
# Colombia        1
# Portugal        1
# Iran            1
# Ukraine         1
# Name: count, dtype: int64

# %%
df.groupby("Country")["Price"].sum()
# Out:
# Country
# Argentina         22.0
# Australia         12.0
# Brazil            95.0
# Canada           153.5
# China            280.0
# Colombia          42.0
# Egypt              8.0
# France           160.0
# Germany          175.0
# India            180.0
# Iran              28.0
# Italy             19.5
# Japan            105.0
# Mexico            80.0
# Morocco           32.0
# Pakistan           4.0
# Poland            45.0
# Portugal         125.0
# Russia             2.5
# Saudi Arabia     120.0
# Singapore         45.0
# South Korea      348.0
# Spain             25.0
# Sweden            28.0
# UAE              305.0
# UK               518.0
# USA             1265.8
# Ukraine           35.0
# Name: Price, dtype: float64

# %%
df.sort_values("Price",ascending=False)
# Out:
#     Order ID      CustomerName                Product     Category  Quantity  \
# 0       1001        John Smith                 Laptop  Electronics         1
# 6       1007       Emily Davis          Standing Desk    Furniture         1
# 2       1003          Ali Khan           Office Chair    Furniture         1
# 14      1015         Lisa Chen              Bookshelf    Furniture         1
# 7       1008        James Park                Monitor  Electronics         2
# 11      1012         Raj Patel           File Cabinet    Furniture         2
# 1       1002         Sarah Lee             Headphones  Electronics         2
# 31      1032     Thomas Müller       Document Scanner  Electronics         1
# 36      1037     Carlos Santos       Wireless Earbuds  Electronics         1
# 19      1020   Fatima Al-Zahra             Whiteboard    Furniture         1
# 28      1029      Seo-yeon Kim      Wireless Keyboard  Electronics         1
# ...

# %% [markdown]
# ## To save data

# %%
df.to_csv("new_file_indexed.csv",index = True) # with index
df.to_csv("new_file_unindexed.csv",index = False) # without index

# %% [markdown]
# ## Thats it will later update advanced
